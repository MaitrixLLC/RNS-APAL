# %% [markdown]
# # Modular Helper Tests
#
# Focused experiments for the exact modular primitives used by digit arithmetic and mixed-radix conversion.
#
# Automated verification: `tests/test_01_modular_helpers.py`. The numbered pytest files establish
# the prerequisite hierarchy before this class or module.

# %%
from pathlib import Path
import sys


def find_repo_root(start=None):
    path = Path.cwd() if start is None else Path(start).resolve()
    for candidate in (path, *path.parents):
        if (candidate / "rns_pypal").exists() and (candidate / "tests").exists():
            return candidate
    raise RuntimeError("Could not find the RNS-PYPAL repository root")


repo_root = find_repo_root()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from rns_pypal import (
    divide_residue_by_coprime_factor,
    multiplicative_inverse,
)

repo_root
# Out:
# WindowsPath('D:/Projects/RNS-APAL-REPO/RNS-APAL')

# %% [markdown]
# ## Multiplicative inverse

# %%
from rns_pypal import multiplicative_inverse

inv = multiplicative_inverse(5, 7)
print(inv)               # 3
print((5 * inv) % 7)     # 1
# Out:
# 3
# 1

# %% [markdown]
# ## Division in a residue channel

# %%
from rns_pypal import divide_residue_by_coprime_factor

value = 26

consumed_modulus = 5
remaining_modulus = 7

consumed_digit = value % consumed_modulus
remaining_residue = value % remaining_modulus

new_residue = divide_residue_by_coprime_factor(
    remaining_residue - consumed_digit,
    consumed_modulus,
    remaining_modulus,
)

print(consumed_digit)   # 1
print(new_residue)      # 5
# Out:
# 1
# 5

# %%
from rns_pypal import divide_residue_by_coprime_factor

q = divide_residue_by_coprime_factor(
    residue=6,
    divisor=5,
    modulus=7,
)

print(q)              # 4
print((q * 5) % 7)    # 6
# Out:
# 4
# 6
